# %%
import pandas as pd
from itertools import combinations
from scipy.stats import zscore
from sklearn.preprocessing import MinMaxScaler
import networkx as nx

from networkx.algorithms import bipartite

# %%
df_small = pd.read_csv("training_data/df_small[drug-protein].csv")
df_large =pd.read_csv("training_data/df_large[drug-protein].csv")

avail_drugs_small = set(df_small['Drug1'].unique().tolist() + df_small['Drug2'].unique().tolist())
avail_drugs_large = set(df_large['Drug1'].unique().tolist() + df_large['Drug2'].unique().tolist())
avail_cells_small = df_small['Cell line'].unique().tolist()

# %%
DC = nx.Graph()

DC.add_nodes_from(avail_drugs_small)
DC.add_nodes_from(avail_cells_small)

edges1 = [(row['Drug1'], row['Cell line'])  for _, row in df_small.iterrows()]
edges2 = [(row['Drug2'], row['Cell line'])  for _, row in df_small.iterrows()]

DC.add_edges_from(edges1)
DC.add_edges_from(edges2)

# %%
df_small.dtypes
# Out:
# Drug1                   object
# Drug2                   object
# Cell line               object
# ZIP                    float64
# Bliss                  float64
# Loewe                  float64
# HSA                    float64
# classification          object
# combination_id          object
# chemical_1              object
# chemical_2              object
# z_score_sum            float64
# min_max_score_sum      float64
# degree_centrality_1    float64
# degree_centrality_2    float64
# clustering_1           float64
# clustering_2           float64
# pagerank_1             float64
# pagerank_2             float64
# closeness_1            float64
# closeness_2            float64
# betweenness_1          float64
# betweenness_2          float64
# dtype: object

# %%
def get_all_stats(DC, avail_drugs_small, df_og):
    drug_projection = bipartite.projected_graph(DC, avail_drugs_small)
    dc_deg_centrality = nx.degree_centrality(drug_projection)
    dc_cc = nx.clustering(drug_projection)
    dc_pagerank = nx.pagerank(drug_projection)
    dc_closeness = nx.closeness_centrality(drug_projection)
    dc_betweenness = nx.betweenness_centrality(drug_projection)

    def add_node_features(df, feature_dict, feature_name):
        df["dc_" + feature_name + "_1"] = df["Drug1"].map(feature_dict)
        df["dc_" + feature_name + "_2"] = df["Drug2"].map(feature_dict)
        return df

    df_og_extra = df_og.copy()

    df_og_extra = add_node_features(
    df_og_extra, dc_deg_centrality, "degree_centrality"
    )
    df_og_extra = add_node_features(df_og_extra, dc_cc, "clustering")
    df_og_extra = add_node_features(df_og_extra, dc_pagerank, "pagerank")
    df_og_extra = add_node_features(df_og_extra, dc_closeness, "closeness")
    df_og_extra = add_node_features(df_og_extra, dc_betweenness, "betweenness")

    return df_og_extra 


df_small_extra = get_all_stats(DC, avail_drugs_small, df_small)
# Out:
# chemical_1    0
# dtype: int64

# %%
df_small_extra.to_csv("training_data/df_small[both].csv",index=False)

# %%
from itertools import combinations 

all_pairs = list(combinations(avail_drugs_small, 2))

existing_pairs = set(tuple(sorted([row['Drug1'], row['Drug2']])) for index, row in df_small.iterrows())
new_pairs = [pair for pair in all_pairs if pair not in existing_pairs]
new_data = []
for cell_line in avail_cells_small:
    for drug1, drug2 in new_pairs:
        new_data.append({
            'Drug1': drug1,
            'Drug2': drug2,
            'Cell line': cell_line
        })

# Create a new dataframe from the new pairs
df_new_combinations = pd.DataFrame(new_data)

df_new_combinations.to_csv("new_combinations.csv",index=False)

# %%
df_drug_protein = pd.read_csv("filtered_data/df_drug_protein_2(normalized).csv")
df_drug_cid = pd.read_csv("filtered_data/df_drug_cid.csv")


def get_avg_z(row):
    z1 = df_drug_protein[df_drug_protein["chemical"] == row[0]]["z_score"]
    z2 = df_drug_protein[df_drug_protein["chemical"] == row[1]]["z_score"]
    return (z1 + z2) / 2


def get_avg_mm(row):
    z1 = df_drug_protein[df_drug_protein["chemical"] == row["chemical_1"]][
        "min_max_score"
    ]
    z2 = df_drug_protein[df_drug_protein["chemical"] == row["chemical_2"]][
        "min_max_score"
    ]
    return (z1 + z2) / 2


def get_test_data(df_new_comb, DC, avail_drugs, sample_size=100):
    df_test = df_new_comb.sample(sample_size).reset_index()
    DC_test = DC.copy()
    edges1 = [(row["Drug1"], row["Cell line"]) for _, row in df_test.iterrows()]
    edges2 = [(row["Drug2"], row["Cell line"]) for _, row in df_test.iterrows()]
    DC_test.add_edges_from(edges1)
    DC_test.add_edges_from(edges2)
    c1 = [
        "Drug1",
        "degree_centrality_1",
        "clustering_1",
        "pagerank_1",
        "closeness_1",
        "betweenness_1",
    ]
    c2 = [
        "Drug2",
        "degree_centrality_2",
        "clustering_2",
        "pagerank_2",
        "closeness_2",
        "betweenness_2",
    ]
    df2 = df_test.merge(df_drug_cid, how="left", left_on="Drug1", right_on="Drug")[
        ["Drug1", "Drug2", "Cell line", "cIds"]
    ]
    df2 = df2.rename(columns={"cIds": "chemical_1"})
    df2 = df2.merge(df_drug_cid[["Drug", "cIds"]], left_on="Drug2", right_on="Drug")[
        ["Drug1", "Drug2", "Cell line", "chemical_1", "cIds"]
    ]
    df2 = df2.rename(columns={"cIds": "chemical_2"})
    df_drug_protein_avg = (
        df_drug_protein[["chemical", "min_max_score", "z_score", "min_max_score"]]
        .groupby("chemical")
        .mean()
        .reset_index()
    )
    df2 = df2.merge(
        df_drug_protein_avg[["chemical", "z_score", "min_max_score"]],
        how="left",
        left_on="chemical_1",
        right_on="chemical",
        suffixes=("", "_1"),
    )
    df2 = df2.merge(
        df_drug_protein_avg[["chemical", "z_score", "min_max_score"]],
        how="left",
        left_on="chemical_2",
        right_on="chemical",
        suffixes=("", "_2"),
    )
    df2["z_score_sum"] = df2[["z_score", "z_score_2"]].mean(axis=1)
    df2["min_max_score_sum"] = df2[["min_max_score", "min_max_score_2"]].mean(axis=1)
    df2.drop(
        columns=[
            "chemical",
            "z_score",
            "z_score_2",
            "chemical_2",
            "chemical_1",
            "min_max_score_2",
            "min_max_score",
        ],
        inplace=True,
    )

    df2 = df2.merge(df_small[c1], on="Drug1", how="left").drop_duplicates()
    df2 = df2.merge(df_small[c2], on='Drug2', how='left').drop_duplicates()
    df2 = df2.dropna()
    df_combined = pd.concat([df_small, test_data]).drop(
    columns=[
        "Bliss",
        "HSA",
        "Loewe",
        "ZIP",
        "chemical_1",
        "chemical_2",
        "classification",
        "combination_id"
        ]
    )

    


print(DC)
test_data = get_test_data(df_new_combinations, DC, avail_drugs_small)

set(df_small.columns) -set(test_data.columns)
# Out:
# Graph with 292 nodes and 2647 edges
# {'Bliss',
#  'HSA',
#  'Loewe',
#  'ZIP',
#  'chemical_1',
#  'chemical_2',
#  'classification',
#  'combination_id'}

# %%
df_combined = pd.concat([df_small, test_data]).drop(
    columns=[
        "Bliss",
        "HSA",
        "Loewe",
        "ZIP",
        "chemical_1",
        "chemical_2",
        "classification",
        "combination_id"
    ]
)

df_combined
# Out:
#                    Drug1          Drug2 Cell line  z_score_sum  \
# 0                (+)-jq1   camptothecin     U-HO1    -0.026083
# 1                (+)-jq1        zolinza    DIPG25    -0.138251
# 2            117048-62-1    chloroquine     TC-32     0.425315
# 3     2-methoxyestradiol   camptothecin     TC-71     0.422009
# 4            200484-11-3  cycloheximide     U-HO1     4.787841
# ...                  ...            ...       ...          ...
# 5643       chembl3348887    thalidomide    OVCAR3     0.104317
# 6219          artesunate      verapamil     T-47D     0.133562
# 6226         selumetinib   lestaurtinib    IGROV1     0.891263
# 6234         hydroxyurea    clopidogrel  COLO 205     0.010436
# 7339              sl-327   theophylline      A498    -0.000116
#
#       min_max_score_sum  degree_centrality_1  degree_centrality_2  \
# 0              0.009509             0.045662             0.215373
# 1              0.013349             0.045662             0.245053
# 2              0.009691             0.009893             0.273212
# 3              0.010783             0.094368             0.215373
# 4              0.073546             0.335616             0.391172
# ...                 ...                  ...                  ...
# 5643           0.209374             0.216895             0.257230
# 6219           0.215059             0.073820             0.298326
# 6226           0.362373             0.090563             0.253425
# 6234           0.191121             0.238204             0.214612
# 7339           0.189070             0.114916             0.249619
#
#       clustering_1  clustering_2  pagerank_1  pagerank_2  closeness_1  \
# 0         0.864407      0.587700    0.000525    0.001798     0.498479
# 1         0.864407      0.513438    0.000525    0.002088     0.498479
# 2         0.782051      0.477412    0.000216    0.002280     0.440782
# 3         0.801600      0.587700    0.000870    0.001798     0.518813
# 4         0.383076      0.324732    0.002839    0.003343     0.598448
# ...            ...           ...         ...         ...          ...
# 5643      0.589795      0.535933    0.001772    0.002071     0.557685
# 6219      0.933634      0.403087    0.000690    0.002596     0.513525
# 6226      0.896026      0.375285    0.000820    0.002812     0.518402
# 6234      0.512042      0.524040    0.002066    0.001854     0.563927
# 7339      0.820221      0.541993    0.001014    0.002000     0.526317
#
#       closeness_2  betweenness_1  betweenness_2
# 0        0.555321       0.000059       0.000485
# 1        0.566855       0.000059       0.001591
# 2        0.575573       0.000007       0.001300
# 3        0.555321       0.000135       0.000485
# 4        0.619094       0.002718       0.003470
# ...           ...            ...            ...
# 5643     0.571555       0.000481       0.000560
# 6219     0.584562       0.000021       0.002849
# 6226     0.567838       0.000020       0.006876
# 6234     0.555793       0.001252       0.001332
# 7339     0.567592       0.000130       0.000705
#
# [11832 rows x 15 columns]

# %%
df2 = test_data.copy()
# Out:
#                  Drug1                             Drug2      Cell line  \
# 0           exemestane                   tranexamic acid         UACC62
# 1              cyanein                    2-fluoro ara-a         HCT-15
# 2           fingolimod                        tacrolimus         SF-268
# 3           artemether                           tacrine     MDA-MB-231
# 4           crizotinib                          orlistat       SK-MEL-5
# 5          vincristine                      lestaurtinib         SF-268
# 6           topiramate                       sulfadoxine          LNCAP
# 7         testosterone                          nutlin-3       NCIH1650
# 8    ethinyl estradiol                       sulfadoxine           A549
# 9             thiotepa                      panobinostat         CAKI-1
# 10        prednisolone                      leptomycin b           OV90
# 11            baclofen                         niraparib        SKMEL30
# 12          triptolide  dideoxycytidine 5\'-triphosphate         OVCAR3
# 13          triptolide  dideoxycytidine 5\'-triphosphate         OVCAR3
# 14           isoniazid                          abacavir       NCI-H460
# 15           buspirone                     metronidazole           DLD1
# 16           letrozole                hydroxychloroquine     MDA-MB-468
# 17           letrozole                          nutlin-3           A549
# 18            axitinib                       vincristine          TC-32
# 19         dronedarone                       mebendazole      RPMI-8226
# 20         chloroquine                       methoxsalen       NCIH1650
# 21        pyridostatin                 dihydroergotamine     MDA-MB-468
# 22           maraviroc                       albendazole         NCIH23
# 23          naltrexone                      cerivastatin         SKMES1
# 24          manidipine                      schembl82368           A375
# 25   trimethobenzamide                         etoposide     MDA-MB-435
# 26         brefeldin a                        vismodegib         SNB-75
# 27        tubastatin a                         pazopanib           U251
# 28         leflunomide                       200484-11-3        NCIH520
# 29  hydroxychloroquine                         ibrutinib  NCI\\/ADR-RES
# 30          artemether                           su-mi-2         SNB-75
# 31         pentamidine                          orlistat        SKMEL30
# 32          naltrexone              navitoclax (abt-263)           HT29
# 33       metronidazole                 ethinyl estradiol         OVCAR3
# 34           reserpine                              5-fu      SK-MEL-28
# 35         fulvestrant                      mocetinostat            PA1
# 36            baclofen                   zoledronic acid           MSTO
# 37             torin-1                   dexmedetomidine        OVCAR-5
# 38         albendazole                 trimethobenzamide          OCUBM
# 39           endoxifen                 bgt-226 free base         L-1236
# 40           erlotinib                      cerivastatin            M14
# 41    methylergonovine                        everolimus     MDA-MB-231
# 42           bleomycin                       thioguanine           HT29
# 43            dopamine                       niclosamide     MDA-MB-231
# 44             mk-2206                 mycophenolic acid         DIPG25
# 45           isoniazid                          cudc-101          K-562
# 46      levonorgestrel                       pracinostat        SK-OV-3
# 47          mesalazine                 vorinostat (saha)           VCAP
# 48           efavirenz                         dasatinib           LOVO
# 49              sl-327                      azithromycin           DLD1
# 50           buspirone           topotecan hydrochloride          UO-31
#
#     z_score_sum  min_max_score_sum
# 0     -0.263524           0.137857
# 1     -0.031262           0.183014
# 2      0.222219           0.232296
# 3     -0.047768           0.179805
# 4      0.037784           0.196438
# 5      1.450062           0.471015
# 6     -0.060105           0.177406
# 7     -0.213970           0.147492
# 8     -0.223907           0.145560
# 9     -0.030577           0.183147
# 10     0.234238           0.234633
# 11    -0.150581           0.159816
# 12    -0.095074           0.170608
# 13     0.135992           0.215532
# 14    -0.065877           0.176284
# 15    -0.098340           0.169973
# 16    -0.126460           0.164505
# 17    -0.155900           0.158782
# 18     0.719290           0.328938
# 19     0.239055           0.235570
# 20     0.046424           0.198118
# 21    -0.006906           0.187749
# 22    -0.225099           0.145328
# 23     0.361845           0.259443
# 24     0.225364           0.232908
# 25    -0.066138           0.176233
# 26     0.060063           0.200770
# 27     0.075407           0.203753
# 28     0.181715           0.224421
# 29     0.106504           0.209799
# 30     0.048726           0.198566
# 31     0.096612           0.207876
# 32     0.171741           0.222482
# 33    -0.132718           0.163289
# 34    -0.102426           0.169178
# 35     0.043023           0.197457
# 36    -0.080089           0.173521
# 37    -0.138278           0.162208
# 38    -0.255400           0.139437
# 39     0.225440           0.232922
# 40     0.386541           0.264244
# 41    -0.093931           0.170830
# 42    -0.017117           0.185764
# 43     0.164634           0.221101
# 44    -0.017804           0.185631
# 45     0.306348           0.248653
# 46    -0.086012           0.172370
# 47    -0.008309           0.187477
# 48    -0.144328           0.161032
# 49    -0.030633           0.183136
# 50    -0.076348           0.174248

# %%
df2
# Out:
#                  Drug1                             Drug2      Cell line  \
# 0           exemestane                   tranexamic acid         UACC62
# 1              cyanein                    2-fluoro ara-a         HCT-15
# 2           fingolimod                        tacrolimus         SF-268
# 3           artemether                           tacrine     MDA-MB-231
# 4           crizotinib                          orlistat       SK-MEL-5
# 5          vincristine                      lestaurtinib         SF-268
# 6           topiramate                       sulfadoxine          LNCAP
# 7         testosterone                          nutlin-3       NCIH1650
# 8    ethinyl estradiol                       sulfadoxine           A549
# 9             thiotepa                      panobinostat         CAKI-1
# 10        prednisolone                      leptomycin b           OV90
# 11            baclofen                         niraparib        SKMEL30
# 12          triptolide  dideoxycytidine 5\'-triphosphate         OVCAR3
# 13          triptolide  dideoxycytidine 5\'-triphosphate         OVCAR3
# 14           isoniazid                          abacavir       NCI-H460
# 15           buspirone                     metronidazole           DLD1
# 16           letrozole                hydroxychloroquine     MDA-MB-468
# 17           letrozole                          nutlin-3           A549
# 18            axitinib                       vincristine          TC-32
# 19         dronedarone                       mebendazole      RPMI-8226
# 20         chloroquine                       methoxsalen       NCIH1650
# 21        pyridostatin                 dihydroergotamine     MDA-MB-468
# 22           maraviroc                       albendazole         NCIH23
# 23          naltrexone                      cerivastatin         SKMES1
# 24          manidipine                      schembl82368           A375
# 25   trimethobenzamide                         etoposide     MDA-MB-435
# 26         brefeldin a                        vismodegib         SNB-75
# 27        tubastatin a                         pazopanib           U251
# 28         leflunomide                       200484-11-3        NCIH520
# 29  hydroxychloroquine                         ibrutinib  NCI\\/ADR-RES
# 30          artemether                           su-mi-2         SNB-75
# 31         pentamidine                          orlistat        SKMEL30
# 32          naltrexone              navitoclax (abt-263)           HT29
# 33       metronidazole                 ethinyl estradiol         OVCAR3
# 34           reserpine                              5-fu      SK-MEL-28
# 35         fulvestrant                      mocetinostat            PA1
# 36            baclofen                   zoledronic acid           MSTO
# 37             torin-1                   dexmedetomidine        OVCAR-5
# 38         albendazole                 trimethobenzamide          OCUBM
# 39           endoxifen                 bgt-226 free base         L-1236
# 40           erlotinib                      cerivastatin            M14
# 41    methylergonovine                        everolimus     MDA-MB-231
# 42           bleomycin                       thioguanine           HT29
# 43            dopamine                       niclosamide     MDA-MB-231
# 44             mk-2206                 mycophenolic acid         DIPG25
# 45           isoniazid                          cudc-101          K-562
# 46      levonorgestrel                       pracinostat        SK-OV-3
# 47          mesalazine                 vorinostat (saha)           VCAP
# 48           efavirenz                         dasatinib           LOVO
# 49              sl-327                      azithromycin           DLD1
# 50           buspirone           topotecan hydrochloride          UO-31
#
#       chemical_1    chemical_2    chemical_2  z_score_sum
# 0   CIDs00060198  CIDs00005526  CIDs00005526    -0.263524
# 1   CIDs05287620  CIDs00657237  CIDs00657237    -0.031262
# 2   CIDs00107969  CIDs00445643  CIDs00445643     0.222219
# 3   CIDs00068911  CIDs00001935  CIDs00001935    -0.047768
# 4   CIDs11626560  CIDs03034010  CIDs03034010     0.037784
# 5   CIDs60138149  CIDs00126565  CIDs00126565     1.450062
# 6   CIDs05284627  CIDs00017134  CIDs00017134    -0.060105
# 7   CIDs00006013  CIDs00216345  CIDs00216345    -0.213970
# 8   CIDs00005991  CIDs00017134  CIDs00017134    -0.223907
# 9   CIDs00005453  CIDs06918837  CIDs06918837    -0.030577
# 10  CIDs00005755  CIDs06917907  CIDs06917907     0.234238
# 11  CIDs00002284  CIDs24958200  CIDs24958200    -0.150581
# 12  CIDs00107985  CIDs00005323  CIDs00005323    -0.095074
# 13  CIDs00107985  CIDs00119119  CIDs00119119     0.135992
# 14  CIDs00003767  CIDs00441300  CIDs00441300    -0.065877
# 15  CIDs00002477  CIDs00004173  CIDs00004173    -0.098340
# 16  CIDs00003902  CIDs00003652  CIDs00003652    -0.126460
# 17  CIDs00003902  CIDs00216345  CIDs00216345    -0.155900
# 18  CIDs06450551  CIDs60138149  CIDs60138149     0.719290
# 19  CIDs00208898  CIDs00004030  CIDs00004030     0.239055
# 20  CIDs00002719  CIDs00004114  CIDs00004114     0.046424
# 21  CIDs25227847  CIDs00010531  CIDs00010531    -0.006906
# 22  CIDs03002977  CIDs00002082  CIDs00002082    -0.225099
# 23  CIDs05360515  CIDs00446156  CIDs00446156     0.361845
# 24  CIDs00004008  CIDs05280443  CIDs05280443     0.225364
# 25  CIDs00005577  CIDs00036462  CIDs00036462    -0.066138
# 26  CIDs05287620  CIDs24776445  CIDs24776445     0.060063
# 27  CIDs49850262  CIDs10113978  CIDs10113978     0.075407
# 28  CIDs00003899  CIDs00008515  CIDs00008515     0.181715
# 29  CIDs00003652  CIDs24821094  CIDs24821094     0.106504
# 30  CIDs00068911  CIDs09549297  CIDs09549297     0.048726
# 31  CIDs00004735  CIDs03034010  CIDs03034010     0.096612
# 32  CIDs05360515  CIDs24978538  CIDs24978538     0.171741
# 33  CIDs00004173  CIDs00005991  CIDs00005991    -0.132718
# 34  CIDs00005770  CIDs00003385  CIDs00003385    -0.102426
# 35  CIDs00104741  CIDs09865515  CIDs09865515     0.043023
# 36  CIDs00002284  CIDs00068740  CIDs00068740    -0.080089
# 37  CIDs49836027  CIDs05311068  CIDs05311068    -0.138278
# 38  CIDs00002082  CIDs00005577  CIDs00005577    -0.255400
# 39  CIDs10090750  CIDs06918289  CIDs06918289     0.225440
# 40  CIDs00176870  CIDs00446156  CIDs00446156     0.386541
# 41  CIDs00008226  CIDs06442177  CIDs06442177    -0.093931
# 42  CIDs05360373  CIDs02723601  CIDs02723601    -0.017117
# 43  CIDs00000681  CIDs00004477  CIDs00004477     0.164634
# 44  CIDs24964624  CIDs00446541  CIDs00446541    -0.017804
# 45  CIDs00003767  CIDs24756910  CIDs24756910     0.306348
# 46  CIDs00013109  CIDs49855250  CIDs49855250    -0.086012
# 47  CIDs00004075  CIDs00005311  CIDs00005311    -0.008309
# 48  CIDs00064139  CIDs03062316  CIDs03062316    -0.144328
# 49  CIDs09549284  CIDs00447043  CIDs00447043    -0.030633
# 50  CIDs00002477  CIDs00060699  CIDs00060699    -0.076348
